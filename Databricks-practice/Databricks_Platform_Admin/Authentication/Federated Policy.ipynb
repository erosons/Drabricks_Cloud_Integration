# %%
# %sh
curl -sS -X POST "https://accounts.cloud.databricks.com/oidc/accounts/67690736-ed9f-4566-9c09-6ce4af6eb2e3/v1/token" \
  -H "Content-Type: application/x-www-form-urlencoded" \
  --data "grant_type=client_credentials&client_id=client&client_secret=client_secret&scope=all-apis"
